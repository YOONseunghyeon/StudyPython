# %% [markdown]
# ## 리스트와 행렬의 차이점
# - 행렬구조에 특화된 numpy 모듈에 대하여서 먼저 학습
# - 행렬은 반드시 행과 열의 갯수가 인덱싱마다 같아야하고, 연산이 가능, 자료의 성격이 같아야 한다.
# - 행렬에 특화된 모듈이 numpy

# %%
from PIL import Image
img=Image.open('./pic/img1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x404 at 0x2D3576B47C0>
